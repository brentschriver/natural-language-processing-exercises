# %%
import unicodedata
import re
import json
import os
from requests import get
from bs4 import BeautifulSoup
import acquire

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords


import pandas as pd
from acquire import get_codeup_blog_urls
from acquire import parse_blog
from acquire import get_article_text
from acquire import get_codeup_blogs
from acquire import get_inshorts

# %% [markdown]
# ## From acquire, use 'get_article_text' function and store results into variable.

# %%
original = get_article_text()

# %%
# Lowercase everything in the text.
article = original.lower()

# %%
print(article)

# %% [markdown]
# ## Remove Accented Characters
#
# Convert invalid characters into ASCII characters.
# 1. 'unicodedata.normalize' will remove inconsistencies in unicode character encoding.
# 2. '.encode' will convert the resulting string to the ASCII character set.
# 3. '.decode' turns the resulting bytes object back into a string.

# %%
article = unicodedata.normalize('NFKD', article)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')

# %%
print(article)

# %% [markdown]
# ## Remove Special Characters

# %%
# Remove anything that isn't a-z, a number, single quote, or whitespace.
article = re.sub(r"[^a-z0-9'\s]", '', article)

# %%
print(article)

# %% [markdown]
# ## Tokenization
# ##### Use nltk to tokenize the strings.

# %%
tokenizer = nltk.tokenize.ToktokTokenizer()

# %%
tokenizer.tokenize(original, return_str=True)
# Out:
# 'What are the Math and Stats Principles You Need for Data Science ? \nOct 21 , 2020 &#124; Data Science\n\n\nComing into our Data Science program , you will need to know some math and stats. However , many of our applicants actually learn in the application process – you don ’ t need to be an expert before applying ! Data science is a very accessible field to anyone dedicated to learning new skills , and we can work with any applicant to help them learn what they need to know. But what “skills ” do we mean , exactly ? Just what exactly are the data science math and stats principles you need to know ? \nWhat are the main math principles you need to know to get into Codeup ’ s Data Science program ? \n\n\nAlgebra\nDo you know PEMDAS and can you solve for x ? You will need to be or become comfortable with the following : \n\nVariables ( x , y , n , etc. ) \nFormulas , functions , and variable manipulations ( e.g. x^2 = x + 6 , solve for x ) .\nOrder of evaluation : PEMDAS : parentheses , exponents , then multiplication , division , addition , and subtraction\nCommutativity where a + b = b + a\nAssociativity where a + ( b + c ) = ( a + b ) + c\nAdding and subtracting matrices\nA conceptual understanding of exponential growth/decay- things can increase at an increasing rate\n\nDescriptive Statistics\nKnow what a min , max , mode , median , and average are. Have a conceptual understanding that stats/probability is about trying to quantify uncertainty.\nData Visualization\nKnow what a scatterplot is and how to read a barplot.\nHow to Learn and Expand on These Concepts\nThere are a number of great resources out there to teach you these and similar concepts. Khan Academy is a great starting place for data science math ! If you want to know what exactly we assign our applicants , you ’ ll just have to apply ! \n \nWhat about once you ’ re in Codeup ? \n\n\nWhat You Won ’ t Do\nDo we do any mathematical proofs for concepts or perform derivations ? No. \nDo we do any calculus and probability calculating by hand ? No.\nAre we transforming equations , where we cancel out units or terms and do lots of algebraic gymnastics ? No\nWhat You Will Do\nWill we have Python solve our linear algebra problems for us ? Yes\nWill we have Python calculate probabilities , the area under a curve , and the slope of a line for us ? Yes\nWill we have Python do all of the calculus for us ? Yes\n \nSee , the data science math and stats slice of the pie is certainly doable. If you like problem-solving and are ready to challenge yourself , you ’ ll love data science ! If you are interested in learning about data science , just apply ! Our Admissions Manager can work with you to get you where you need to be starting from where you are now. Let us help you get there so you can launch a great new career.\n\n\n\n\n\n\n\n\nOur ProgramsFull Stack Web Development\nData Science\nSystems Engineering\n\n\n\n\n\nLatest Blog Articles\nCodeup Start Dates for March 2022\nVET TEC Funding Now Available For Dallas Veterans\nDallas Campus Re-opens With New Grant Partner\nCodeup Dallas Open House\nCodeup ’ s Placement Team Continues Setting Records'

# %% [markdown]
# ## Stemming and Lemmatization
# ### Stemming
# Reducing words to its root stem. The root stem may not always be an official word found in a dictionary.

# %%
# Create the nltk stemmer object, then use it
ps = nltk.porter.PorterStemmer()

ps.stem('call'), ps.stem('called'), ps.stem('calling')

# %%
# Apply stemming transformation to all the words in the article.
stems = [ps.stem(word) for word in article.split()]

# %%
# Join each word in 'stems' with a space.
article_stemmed = ' '.join(stems)

# %%
print(article_stemmed)

# %%
pd.Series(stems).value_counts().head(5)

# %% [markdown]
# ## Lemmatization
# The base form of a lemmatized word is the root word(lemma). Lemmas will always be present in dictionaries.

# %%
# Create lemmatizer object
wnl = nltk.stem.WordNetLemmatizer()

for word in 'study studies come coming eat eatery eating eaters'.split():
    print('stem:', ps.stem(word), '-- lemma:', wnl.lemmatize(word))

# %%
lemmas = [wnl.lemmatize(word) for word in article.split()]
article_lemmatized = ' '.join(lemmas)

# %%
print(article_lemmatized)

# %% [markdown]
# ## Removing Stopwords
# **stopword:** words that have little to no significance while constructing meaningful features from text.
# * Articles, conjunctions, and prepositions are some examples of stopwords.

# %%
stopword_list = stopwords.words('english')
#stopword_list.remove('no')
#stopword_list.remove('not')

# %%
stopword_list

# %%
words = article.split()

# %%
filtered_words = [w for w in words if w not in stopword_list]

print('Removed {} stopwords'.format(len(words) - len(filtered_words)))
print('---')

article_without_stopwords = ' '.join(filtered_words)

print(article_without_stopwords)

# %%
def basic_clean(string):
    # Lowercase everything in the text.
    lower = string.lower()
    lower = unicodedata.normalize('NFKD', lower)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')
    # Remove anything that isn't a-z, a number, single quote, or whitespace.
    cleaned = re.sub(r"[^a-z0-9'\s]", '', lower)
    return cleaned

# %%
def tokenize(string):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    return tokenizer.tokenize(string, return_str=True)

# %%
def stem(string):
    # Create the nltk stemmer object, then use it
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in string.split()]
    article_stemmed = ' '.join(stems)
    return article_stemmed

# %%
def lemmatize(string):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    article_lemmatized = ' '.join(lemmas)
    return article_lemmatized

# %%
def remove_stopwords(string):
    stopword_list = stopwords.words('english')
    words = string.split()
    filtered_words = [w for w in words if w not in stopword_list]
    print('Removed {} stopwords'.format(len(words) - len(filtered_words)))
    print('---')
    string_without_stopwords = ' '.join(filtered_words)
    return string_without_stopwords

# %%
urls = get_codeup_blog_urls()
# Out:
# /Users/brent/codeup-data-science/natural-language-processing-exercises/acquire.py:29: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 29 of the file /Users/brent/codeup-data-science/natural-language-processing-exercises/acquire.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(response.text)

# %%
urls
# Out:
# [<a class="more-link" href="https://codeup.com/dallas-newsletter/codeup-dallas-open-house/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeups-placement-team-continues-setting-records/">read more</a>,
#  <a class="more-link" href="https://codeup.com/it-training/it-certifications-101/">read more</a>,
#  <a class="more-link" href="https://codeup.com/cybersecurity/a-rise-in-cyber-attacks-means-opportunities-for-veterans-in-san-antonio/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/use-your-gi-bill-benefits-to-land-a-job-in-tech/">read more</a>,
#  <a class="more-link" href="https://codeup.com/tips-for-prospective-students/which-program-is-right-for-me-cyber-security-or-systems-engineering/">read more</a>,
#  <a class="more-link" href="https://codeup.com/it-training/what-the-heck-is-system-engineering/">read more</a>,
#  <a class="more-link" href="https://codeup.com/alumni-stories/from-speech-pathology-to-business-intelligence/">read more</a>,
#  <a class="more-link" href="https://codeup.com/behind-the-billboards/boris-behind-the-billboards/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/is-codeup-the-best-bootcamp-in-san-antonio-or-the-world/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeup-launches-first-podcast-hire-tech/">read more</a>,
#  <a class="more-link" href="https://codeup.com/tips-for-prospective-students/why-should-i-become-a-system-administrator/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeup-candidate-for-accreditation/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeup-takes-over-more-of-the-historic-vogue-building/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/inclusion-at-codeup-during-pride-month-and-always/">read more</a>]

# %%
codeup_df = get_codeup_blogs(urls)
# Out:
# /Users/brent/codeup-data-science/natural-language-processing-exercises/acquire.py:37: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 37 of the file /Users/brent/codeup-data-science/natural-language-processing-exercises/acquire.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   blog = BeautifulSoup(response.text)

# %%
codeup_df
# Out:
#                                                 title  \
# 0                            Codeup Dallas Open House
# 1   Codeup’s Placement Team Continues Setting Records
# 2   IT Certifications 101: Why They Matter, and Wh...
# 3   A rise in cyber attacks means opportunities fo...
# 4    Use your GI Bill® benefits to Land a Job in Tech
# 5   Which program is right for me: Cyber Security ...
# 6                What the Heck is System Engineering?
# 7      From Speech Pathology to Business Intelligence
# 8                       Boris – Behind the Billboards
# 9   Is Codeup the Best Bootcamp in San Antonio…or ...
# 10           Codeup Launches First Podcast: Hire Tech
# 11        Why Should I Become a System Administrator?
# 12        Announcing our Candidacy for Accreditation!
# 13  Codeup Takes Over More of the Historic Vogue B...
# 14  Inclusion at Codeup During Pride Month (and Al...
#
#                                         date & source  \
# 0            Nov 30, 2021 | Dallas Newsletter, Events
# 1               Nov 19, 2021 | Codeup News, Employers
# 2   Nov 18, 2021 | IT Training, Tips for Prospecti...
# 3                        Nov 17, 2021 | Cybersecurity
# 4   Nov 4, 2021 | Codeup News, Tips for Prospectiv...
# 5   Oct 28, 2021 | IT Training, Tips for Prospecti...
# 6   Oct 21, 2021 | IT Training, Tips for Prospecti...
# 7                       Oct 18, 2021 | Alumni Stories
# 8                 Oct 3, 2021 | Behind the Billboards
# 9                Sep 16, 2021 | Codeup News, Featured
# 10               Aug 25, 2021 | Codeup News, Featured
# 11  Aug 23, 2021 | IT Training, Tips for Prospecti...
# 12                         Jun 30, 2021 | Codeup News
# 13               Jun 21, 2021 | Codeup News, Featured
# 14                          Jun 4, 2021 | Codeup News
#
#                                               content
# 0   \nCome join us for the re-opening of our Dalla...
# 1   \n\n\n\n\n\nOur Placement Team is simply defin...
# 2   \n\n\n\n\n\nAWS, Google, Azure, Red Hat, CompT...
# 3   \nIn the last few months, the US has experienc...
# 4   \n\n\n\n\n\nAs the end of military service get...
# 5   \n\n\n\n\n\nWhat IT Career should I choose?\nI...
# 6   \n\n\n\n\n\nCodeup offers a 13-week training p...
# 7   \n\n\n\n\n\nBy: Alicia Gonzalez\nBefore Codeup...
# 8                                              \n\n\n
# 9   \n\n\n\n\n\nLooking for the best data science ...
# 10  \nAny podcast enthusiasts out there? We are pl...
# 11  \n\n\n\n\n\nWith so many tech careers in deman...
# 12  \nDid you know that even though we’re an indep...
# 13  \nCodeup is moving into another floor of our H...
# 14  \nHappy Pride Month! Pride Month is a dedicate...

# %%
def prep_text(df):
    if 'content' in df.columns:
        df.content = df.content.str.replace('\n',' ')
        df.content = df.content.str.strip()
        df['clean'] = df.content.apply(basic_clean)
        df['stemmed'] = df.content.apply(stem)
        df['lemmatized'] = df.content.apply(lemmatize)
        return df
    else:
        print("Dataframe does not have required column 'content'.")

# %%
# Create a a dataframe with the column 'content' dropped and run it
# through the newly created function to see if it performs as 
# expected.

# b = codeup_df.drop(columns='content',inplace = True)

# %%
prep_text(codeup_df)
# Out:
#                                                 title  \
# 0                            Codeup Dallas Open House
# 1   Codeup’s Placement Team Continues Setting Records
# 2   IT Certifications 101: Why They Matter, and Wh...
# 3   A rise in cyber attacks means opportunities fo...
# 4    Use your GI Bill® benefits to Land a Job in Tech
# 5   Which program is right for me: Cyber Security ...
# 6                What the Heck is System Engineering?
# 7      From Speech Pathology to Business Intelligence
# 8                       Boris – Behind the Billboards
# 9   Is Codeup the Best Bootcamp in San Antonio…or ...
# 10           Codeup Launches First Podcast: Hire Tech
# 11        Why Should I Become a System Administrator?
# 12        Announcing our Candidacy for Accreditation!
# 13  Codeup Takes Over More of the Historic Vogue B...
# 14  Inclusion at Codeup During Pride Month (and Al...
#
#                                         date & source  \
# 0            Nov 30, 2021 | Dallas Newsletter, Events
# 1               Nov 19, 2021 | Codeup News, Employers
# 2   Nov 18, 2021 | IT Training, Tips for Prospecti...
# 3                        Nov 17, 2021 | Cybersecurity
# 4   Nov 4, 2021 | Codeup News, Tips for Prospectiv...
# 5   Oct 28, 2021 | IT Training, Tips for Prospecti...
# 6   Oct 21, 2021 | IT Training, Tips for Prospecti...
# 7                       Oct 18, 2021 | Alumni Stories
# 8                 Oct 3, 2021 | Behind the Billboards
# 9                Sep 16, 2021 | Codeup News, Featured
# 10               Aug 25, 2021 | Codeup News, Featured
# 11  Aug 23, 2021 | IT Training, Tips for Prospecti...
# 12                         Jun 30, 2021 | Codeup News
# 13               Jun 21, 2021 | Codeup News, Featured
# 14                          Jun 4, 2021 | Codeup News
#
#                                               content  \
# 0   Come join us for the re-opening of our Dallas ...
# 1   Our Placement Team is simply defined as a grou...
# 2   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 3   In the last few months, the US has experienced...
# 4   As the end of military service gets closer, ma...
# 5   What IT Career should I choose? If you’re thin...
# 6   Codeup offers a 13-week training program: Syst...
# 7   By: Alicia Gonzalez Before Codeup, I was a hom...
# 8
# 9   Looking for the best data science bootcamp in ...
# 10  Any podcast enthusiasts out there? We are plea...
# 11  With so many tech careers in demand, why choos...
# 12  Did you know that even though we’re an indepen...
# 13  Codeup is moving into another floor of our His...
# 14  Happy Pride Month! Pride Month is a dedicated ...
#
#                                                 clean  \
# 0   come join us for the reopening of our dallas c...
# 1   our placement team is simply defined as a grou...
# 2   aws google azure red hat comptiathese are big ...
# 3   in the last few months the us has experienced ...
# 4   as the end of military service gets closer man...
# 5   what it career should i choose if youre thinki...
# 6   codeup offers a 13week training program system...
# 7   by alicia gonzalez before codeup i was a home ...
# 8
# 9   looking for the best data science bootcamp in ...
# 10  any podcast enthusiasts out there we are pleas...
# 11  with so many tech careers in demand why choose...
# 12  did you know that even though were an independ...
# 13  codeup is moving into another floor of our his...
# 14  happy pride month pride month is a dedicated t...
#
#                                               stemmed  \
# 0   come join us for the re-open of our dalla camp...
# 1   our placement team is simpli defin as a group ...
# 2   aws, google, azure, red hat, comptia…thes are ...
# 3   in the last few months, the us ha experienc do...
# 4   as the end of militari servic get closer, mani...
# 5   what it career should i choose? if you’r think...
# 6   codeup offer a 13-week train program: system e...
# 7   by: alicia gonzalez befor codeup, i wa a home ...
# 8
# 9   look for the best data scienc bootcamp in the ...
# 10  ani podcast enthusiast out there? we are pleas...
# 11  with so mani tech career in demand, whi choos ...
# 12  did you know that even though we’r an independ...
# 13  codeup is move into anoth floor of our histor ...
# 14  happi pride month! pride month is a dedic time...
#
#                                            lemmatized
# 0   Come join u for the re-opening of our Dallas C...
# 1   Our Placement Team is simply defined a a group...
# 2   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 3   In the last few months, the US ha experienced ...
# 4   As the end of military service get closer, man...
# 5   What IT Career should I choose? If you’re thin...
# 6   Codeup offer a 13-week training program: Syste...
# 7   By: Alicia Gonzalez Before Codeup, I wa a home...
# 8
# 9   Looking for the best data science bootcamp in ...
# 10  Any podcast enthusiast out there? We are pleas...
# 11  With so many tech career in demand, why choose...
# 12  Did you know that even though we’re an indepen...
# 13  Codeup is moving into another floor of our His...
# 14  Happy Pride Month! Pride Month is a dedicated ...

# %%
codeup_df.content = codeup_df.content.str.replace('\n',' ')

# %%
codeup_df.content = codeup_df.content.str.strip()

# %%
codeup_df['clean'] = codeup_df.content.apply(basic_clean)

# %%
codeup_df['stemmed'] = codeup_df.content.apply(stem)

# %%
codeup_df['lemmatized'] = codeup_df.content.apply(lemmatize)

# %%
codeup_df
# Out:
#                                                 title  \
# 0                            Codeup Dallas Open House
# 1   Codeup’s Placement Team Continues Setting Records
# 2   IT Certifications 101: Why They Matter, and Wh...
# 3   A rise in cyber attacks means opportunities fo...
# 4    Use your GI Bill® benefits to Land a Job in Tech
# 5   Which program is right for me: Cyber Security ...
# 6                What the Heck is System Engineering?
# 7      From Speech Pathology to Business Intelligence
# 8                       Boris – Behind the Billboards
# 9   Is Codeup the Best Bootcamp in San Antonio…or ...
# 10           Codeup Launches First Podcast: Hire Tech
# 11        Why Should I Become a System Administrator?
# 12        Announcing our Candidacy for Accreditation!
# 13  Codeup Takes Over More of the Historic Vogue B...
# 14  Inclusion at Codeup During Pride Month (and Al...
#
#                                         date & source  \
# 0            Nov 30, 2021 | Dallas Newsletter, Events
# 1               Nov 19, 2021 | Codeup News, Employers
# 2   Nov 18, 2021 | IT Training, Tips for Prospecti...
# 3                        Nov 17, 2021 | Cybersecurity
# 4   Nov 4, 2021 | Codeup News, Tips for Prospectiv...
# 5   Oct 28, 2021 | IT Training, Tips for Prospecti...
# 6   Oct 21, 2021 | IT Training, Tips for Prospecti...
# 7                       Oct 18, 2021 | Alumni Stories
# 8                 Oct 3, 2021 | Behind the Billboards
# 9                Sep 16, 2021 | Codeup News, Featured
# 10               Aug 25, 2021 | Codeup News, Featured
# 11  Aug 23, 2021 | IT Training, Tips for Prospecti...
# 12                         Jun 30, 2021 | Codeup News
# 13               Jun 21, 2021 | Codeup News, Featured
# 14                          Jun 4, 2021 | Codeup News
#
#                                               content  \
# 0   Come join us for the re-opening of our Dallas ...
# 1   Our Placement Team is simply defined as a grou...
# 2   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 3   In the last few months, the US has experienced...
# 4   As the end of military service gets closer, ma...
# 5   What IT Career should I choose? If you’re thin...
# 6   Codeup offers a 13-week training program: Syst...
# 7   By: Alicia Gonzalez Before Codeup, I was a hom...
# 8
# 9   Looking for the best data science bootcamp in ...
# 10  Any podcast enthusiasts out there? We are plea...
# 11  With so many tech careers in demand, why choos...
# 12  Did you know that even though we’re an indepen...
# 13  Codeup is moving into another floor of our His...
# 14  Happy Pride Month! Pride Month is a dedicated ...
#
#                                                 clean  \
# 0   come join us for the reopening of our dallas c...
# 1   our placement team is simply defined as a grou...
# 2   aws google azure red hat comptiathese are big ...
# 3   in the last few months the us has experienced ...
# 4   as the end of military service gets closer man...
# 5   what it career should i choose if youre thinki...
# 6   codeup offers a 13week training program system...
# 7   by alicia gonzalez before codeup i was a home ...
# 8
# 9   looking for the best data science bootcamp in ...
# 10  any podcast enthusiasts out there we are pleas...
# 11  with so many tech careers in demand why choose...
# 12  did you know that even though were an independ...
# 13  codeup is moving into another floor of our his...
# 14  happy pride month pride month is a dedicated t...
#
#                                               stemmed  \
# 0   come join us for the re-open of our dalla camp...
# 1   our placement team is simpli defin as a group ...
# 2   aws, google, azure, red hat, comptia…thes are ...
# 3   in the last few months, the us ha experienc do...
# 4   as the end of militari servic get closer, mani...
# 5   what it career should i choose? if you’r think...
# 6   codeup offer a 13-week train program: system e...
# 7   by: alicia gonzalez befor codeup, i wa a home ...
# 8
# 9   look for the best data scienc bootcamp in the ...
# 10  ani podcast enthusiast out there? we are pleas...
# 11  with so mani tech career in demand, whi choos ...
# 12  did you know that even though we’r an independ...
# 13  codeup is move into anoth floor of our histor ...
# 14  happi pride month! pride month is a dedic time...
#
#                                            lemmatized
# 0   Come join u for the re-opening of our Dallas C...
# 1   Our Placement Team is simply defined a a group...
# 2   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 3   In the last few months, the US ha experienced ...
# 4   As the end of military service get closer, man...
# 5   What IT Career should I choose? If you’re thin...
# 6   Codeup offer a 13-week training program: Syste...
# 7   By: Alicia Gonzalez Before Codeup, I wa a home...
# 8
# 9   Looking for the best data science bootcamp in ...
# 10  Any podcast enthusiast out there? We are pleas...
# 11  With so many tech career in demand, why choose...
# 12  Did you know that even though we’re an indepen...
# 13  Codeup is moving into another floor of our His...
# 14  Happy Pride Month! Pride Month is a dedicated ...

# %%
news_df = get_inshorts()
# Out:
# /Users/brent/codeup-data-science/natural-language-processing-exercises/acquire.py:80: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 80 of the file /Users/brent/codeup-data-science/natural-language-processing-exercises/acquire.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(response.text)

# %%
news_df
# Out:
#                                                  title       category  \
# 0    Omicron BA.2 found in 57 countries, doesn't se...        science
# 1    Picture of Mars crater that looks like a tree ...        science
# 2    Satellite images show the world's longest 768-...        science
# 3    9.9 crore-year-old flowers found perfectly pre...        science
# 4    Astronaut shares pics of clouds taken from spa...        science
# ..                                                 ...            ...
# 120  Told Deepika won't click pic with you, I'll do...  entertainment
# 121  Troll asks Sara 'Why are your shayris bad?', s...  entertainment
# 122  Brotherhood created with Tom, Tobey over diffi...  entertainment
# 123  Javed confirms Farhan-Shibani's wedding, will ...  entertainment
# 124  Why do we presume that you'll die if you get c...  entertainment
#
#                author                                            content
# 0        Apaar Sharma  Omicron BA.2 variant has been found in 57 coun...
# 1      Pragya Swastik  The European Space Agency (ESA) has released a...
# 2      Pragya Swastik  Satellite images have captured the 768-km-long...
# 3        Ankush Verma  Two 9.9 crore-year-old flowers have been found...
# 4         Daisy Mowke  Astronaut Kayla Barron, who is currently aboar...
# ..                ...                                                ...
# 120     Kriti Kambiri  Actor Dhairya Karwa revealed that he went to D...
# 121  Mahima Kharbanda  Taking to Instagram, actress Sara Ali Khan sha...
# 122     Kriti Kambiri  Actor Andrew Garfield revealed that a brotherh...
# 123     Kriti Kambiri  Lyricist Javed Akhtar has confirmed actor Farh...
# 124     Kriti Kambiri  Actor-filmmaker Mahesh Manjrekar has stated, "...
#
# [125 rows x 4 columns]

# %%
prep_text(news_df)
# Out:
#                                                  title       category  \
# 0    Omicron BA.2 found in 57 countries, doesn't se...        science
# 1    Picture of Mars crater that looks like a tree ...        science
# 2    Satellite images show the world's longest 768-...        science
# 3    9.9 crore-year-old flowers found perfectly pre...        science
# 4    Astronaut shares pics of clouds taken from spa...        science
# ..                                                 ...            ...
# 120  Told Deepika won't click pic with you, I'll do...  entertainment
# 121  Troll asks Sara 'Why are your shayris bad?', s...  entertainment
# 122  Brotherhood created with Tom, Tobey over diffi...  entertainment
# 123  Javed confirms Farhan-Shibani's wedding, will ...  entertainment
# 124  Why do we presume that you'll die if you get c...  entertainment
#
#                author                                            content  \
# 0        Apaar Sharma  Omicron BA.2 variant has been found in 57 coun...
# 1      Pragya Swastik  The European Space Agency (ESA) has released a...
# 2      Pragya Swastik  Satellite images have captured the 768-km-long...
# 3        Ankush Verma  Two 9.9 crore-year-old flowers have been found...
# 4         Daisy Mowke  Astronaut Kayla Barron, who is currently aboar...
# ..                ...                                                ...
# 120     Kriti Kambiri  Actor Dhairya Karwa revealed that he went to D...
# 121  Mahima Kharbanda  Taking to Instagram, actress Sara Ali Khan sha...
# 122     Kriti Kambiri  Actor Andrew Garfield revealed that a brotherh...
# 123     Kriti Kambiri  Lyricist Javed Akhtar has confirmed actor Farh...
# 124     Kriti Kambiri  Actor-filmmaker Mahesh Manjrekar has stated, "...
#
#                                                  clean  \
# 0    omicron ba2 variant has been found in 57 count...
# 1    the european space agency esa has released a p...
# 2    satellite images have captured the 768kmlong l...
# 3    two 99 croreyearold flowers have been found pe...
# 4    astronaut kayla barron who is currently aboard...
# ..                                                 ...
# 120  actor dhairya karwa revealed that he went to d...
# 121  taking to instagram actress sara ali khan shar...
# 122  actor andrew garfield revealed that a brotherh...
# 123  lyricist javed akhtar has confirmed actor farh...
# 124  actorfilmmaker mahesh manjrekar has stated why...
#
#                                                stemmed  \
# 0    omicron ba.2 variant ha been found in 57 count...
# 1    the european space agenc (esa) ha releas a pic...
# 2    satellit imag have captur the 768-km-long ligh...
# 3    two 9.9 crore-year-old flower have been found ...
# 4    astronaut kayla barron, who is current aboard ...
# ..                                                 ...
# 120  actor dhairya karwa reveal that he went to dee...
# 121  take to instagram, actress sara ali khan share...
# 122  actor andrew garfield reveal that a brotherhoo...
# 123  lyricist jave akhtar ha confirm actor farhan a...
# 124  actor-filmmak mahesh manjrekar ha stated, "whi...
#
#                                             lemmatized
# 0    Omicron BA.2 variant ha been found in 57 count...
# 1    The European Space Agency (ESA) ha released a ...
# 2    Satellite image have captured the 768-km-long ...
# 3    Two 9.9 crore-year-old flower have been found ...
# 4    Astronaut Kayla Barron, who is currently aboar...
# ..                                                 ...
# 120  Actor Dhairya Karwa revealed that he went to D...
# 121  Taking to Instagram, actress Sara Ali Khan sha...
# 122  Actor Andrew Garfield revealed that a brotherh...
# 123  Lyricist Javed Akhtar ha confirmed actor Farha...
# 124  Actor-filmmaker Mahesh Manjrekar ha stated, "W...
#
# [125 rows x 7 columns]

# %%
news_df
# Out:
#                                                  title       category  \
# 0    Omicron BA.2 found in 57 countries, doesn't se...        science
# 1    Picture of Mars crater that looks like a tree ...        science
# 2    Satellite images show the world's longest 768-...        science
# 3    9.9 crore-year-old flowers found perfectly pre...        science
# 4    Astronaut shares pics of clouds taken from spa...        science
# ..                                                 ...            ...
# 120  Told Deepika won't click pic with you, I'll do...  entertainment
# 121  Troll asks Sara 'Why are your shayris bad?', s...  entertainment
# 122  Brotherhood created with Tom, Tobey over diffi...  entertainment
# 123  Javed confirms Farhan-Shibani's wedding, will ...  entertainment
# 124  Why do we presume that you'll die if you get c...  entertainment
#
#                author                                            content  \
# 0        Apaar Sharma  Omicron BA.2 variant has been found in 57 coun...
# 1      Pragya Swastik  The European Space Agency (ESA) has released a...
# 2      Pragya Swastik  Satellite images have captured the 768-km-long...
# 3        Ankush Verma  Two 9.9 crore-year-old flowers have been found...
# 4         Daisy Mowke  Astronaut Kayla Barron, who is currently aboar...
# ..                ...                                                ...
# 120     Kriti Kambiri  Actor Dhairya Karwa revealed that he went to D...
# 121  Mahima Kharbanda  Taking to Instagram, actress Sara Ali Khan sha...
# 122     Kriti Kambiri  Actor Andrew Garfield revealed that a brotherh...
# 123     Kriti Kambiri  Lyricist Javed Akhtar has confirmed actor Farh...
# 124     Kriti Kambiri  Actor-filmmaker Mahesh Manjrekar has stated, "...
#
#                                                  clean  \
# 0    omicron ba2 variant has been found in 57 count...
# 1    the european space agency esa has released a p...
# 2    satellite images have captured the 768kmlong l...
# 3    two 99 croreyearold flowers have been found pe...
# 4    astronaut kayla barron who is currently aboard...
# ..                                                 ...
# 120  actor dhairya karwa revealed that he went to d...
# 121  taking to instagram actress sara ali khan shar...
# 122  actor andrew garfield revealed that a brotherh...
# 123  lyricist javed akhtar has confirmed actor farh...
# 124  actorfilmmaker mahesh manjrekar has stated why...
#
#                                                stemmed  \
# 0    omicron ba.2 variant ha been found in 57 count...
# 1    the european space agenc (esa) ha releas a pic...
# 2    satellit imag have captur the 768-km-long ligh...
# 3    two 9.9 crore-year-old flower have been found ...
# 4    astronaut kayla barron, who is current aboard ...
# ..                                                 ...
# 120  actor dhairya karwa reveal that he went to dee...
# 121  take to instagram, actress sara ali khan share...
# 122  actor andrew garfield reveal that a brotherhoo...
# 123  lyricist jave akhtar ha confirm actor farhan a...
# 124  actor-filmmak mahesh manjrekar ha stated, "whi...
#
#                                             lemmatized
# 0    Omicron BA.2 variant ha been found in 57 count...
# 1    The European Space Agency (ESA) ha released a ...
# 2    Satellite image have captured the 768-km-long ...
# 3    Two 9.9 crore-year-old flower have been found ...
# 4    Astronaut Kayla Barron, who is currently aboar...
# ..                                                 ...
# 120  Actor Dhairya Karwa revealed that he went to D...
# 121  Taking to Instagram, actress Sara Ali Khan sha...
# 122  Actor Andrew Garfield revealed that a brotherh...
# 123  Lyricist Javed Akhtar ha confirmed actor Farha...
# 124  Actor-filmmaker Mahesh Manjrekar ha stated, "W...
#
# [125 rows x 7 columns]
